# %%
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords 
from nltk.stem.porter import PorterStemmer
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from numpy.linalg import norm
from sklearn.metrics.pairwise import cosine_similarity

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/vincentzhao/nltk_data...
# True

# %%
dict_df = pd.read_csv("data/dictionary.csv")

dict_df
# Out:
#               Word    POS                                         Definition
# 0                A    NaN  The first letter of the English and of many ot...
# 1                A    NaN  The name of the sixth tone in the model major ...
# 2                A    NaN  An adjective commonly called the indefinite ar...
# 3                A    NaN  In each; to or for each; as """"twenty leagues...
# 4                A  prep.                                    In; on; at; by.
# ...            ...    ...                                                ...
# 175718     Zymotic     a.        Of pertaining to or caused by fermentation.
# 175719     Zymotic     a.  Designating or pertaining to a certain class o...
# 175720      Zythem     n.                                        See Zythum.
# 175721  Zythepsary     n.                                         A brewery.
# 175722      Zythum     n.  A kind of ancient malt beverage; a liquor made...
#
# [175723 rows x 3 columns]

# %%
words = [
    "CRAB", "RAY", "SPONGE", "SQUID", 
    "CIRCLE", "DIAMOND", "SQUARE", "TRIANGLE",
    "BOB", "CROSS", "HOOK", "WEAVE",
    "FEAST", "FREE", "PANTS", "THAT"
]

# %%
dict_df["Word"] = dict_df["Word"].str.upper()

# %%
dict_df = dict_df[dict_df["Word"].isin(words)]

dict_df = dict_df.reset_index()
dict_df
# Out:
#       index   Word    POS                                         Definition
# 0     17498    BOB     n.  Anything that hangs so as to play loosely or w...
# 1     17499    BOB     n.  A knot of worms or of rags on a string used in...
# 2     17500    BOB     n.  A small piece of cork or light wood attached t...
# 3     17501    BOB     n.  The ball or heavy part of a pendulum; also the...
# 4     17502    BOB     n.  A small wheel made of leather with rounded edg...
# ..      ...    ...    ...                                                ...
# 202  171769  WEAVE  v. t.  To unite as threads of any kind in such a mann...
# 203  171770  WEAVE  v. t.  To form as cloth by interlacing threads; to co...
# 204  171771  WEAVE  v. i.          To practice weaving; to work with a loom.
# 205  171772  WEAVE  v. i.                     To become woven or interwoven.
# 206  171773  WEAVE     n.  A particular method or pattern of weaving; as ...
#
# [207 rows x 4 columns]

# %%
port_stem = PorterStemmer()
lemma = nltk.wordnet.WordNetLemmatizer()
sno = nltk.stem.SnowballStemmer('english')
stop = stopwords.words("english")

# %%
def stemming(content):
    stemmed_content = re.sub('[^a-zA-Z]', ' ', content) # remove non alphabetical characters
    stemmed_content = stemmed_content.lower() # convert all to lower
    stemmed_content = stemmed_content.split() # convert to word list
    
    stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stop] # stem all words except those that are stopwords
    
    return ' '.join(stemmed_content) # return reconstructed list as a string

# %%
dict_df["stemmed"] = dict_df["Definition"].apply(stemming)

dict_df
# Out:
#       index   Word    POS                                         Definition  \
# 0     17498    BOB     n.  Anything that hangs so as to play loosely or w...
# 1     17499    BOB     n.  A knot of worms or of rags on a string used in...
# 2     17500    BOB     n.  A small piece of cork or light wood attached t...
# 3     17501    BOB     n.  The ball or heavy part of a pendulum; also the...
# 4     17502    BOB     n.  A small wheel made of leather with rounded edg...
# ..      ...    ...    ...                                                ...
# 202  171769  WEAVE  v. t.  To unite as threads of any kind in such a mann...
# 203  171770  WEAVE  v. t.  To form as cloth by interlacing threads; to co...
# 204  171771  WEAVE  v. i.          To practice weaving; to work with a loom.
# 205  171772  WEAVE  v. i.                     To become woven or interwoven.
# 206  171773  WEAVE     n.  A particular method or pattern of weaving; as ...
#
#                                                stemmed
# 0    anyth hang play loos short abrupt motion end s...
# 1    knot worm rag string use angl eel formerli wor...
# 2    small piec cork light wood attach fish line sh...
# 3    ball heavi part pendulum also ball weight end ...
# 4    small wheel made leather round edg use polish ...
# ..                                                 ...
# 202  unit thread kind manner form textur entwin int...
# 203  form cloth interlac thread compos textur kind ...
# 204                             practic weav work loom
# 205                             becom woven interwoven
# 206       particular method pattern weav cassimer weav
#
# [207 rows x 5 columns]

# %%
dict_df[dict_df["Word"] == "CROSS"]
# Out:
#     index   Word    POS                                         Definition  \
# 46  36503  CROSS     n.  A gibbet consisting of two pieces of timber pl...
# 47  36504  CROSS     n.  The sign or mark of the cross made with the fi...
# 48  36505  CROSS     n.  Affiction regarded as a test of patience or vi...
# 49  36506  CROSS     n.  A piece of money stamped with the figure of a ...
# 50  36507  CROSS     n.  An appendage or ornament or anything in the fo...
# 51  36508  CROSS     n.  A monument in the form of a cross or surmounte...
# 52  36509  CROSS     n.  A common heraldic bearing of which there are m...
# 53  36510  CROSS     n.  The crosslike mark or symbol used instead of a...
# 54  36511  CROSS     n.                                      Church lands.
# 55  36512  CROSS     n.       A line drawn across or through another line.
# 56  36513  CROSS     n.  A mixing of breeds or stock especially in catt...
# 57  36514  CROSS     n.  An instrument for laying of offsets perpendicu...
# 58  36515  CROSS     n.  A pipe-fitting with four branches the axes of ...
# 59  36516  CROSS     a.  Not parallel; lying or falling athwart; transv...
# 60  36517  CROSS     a.  Not accordant with what is wished or expected;...
# 61  36518  CROSS     a.  Characterized by or in a state of peevishness ...
# 62  36519  CROSS     a.  Made in an opposite direction or an inverse re...
# 63  36520  CROSS  prep.                                   Athwart; across.
# 64  36523  CROSS  v. t.  To put across or athwart; to cause to intersec...
# 65  36524  CROSS  v. t.  To lay or draw something as a line across; as ...
# 66  36525  CROSS  v. t.  To pass from one side to the other of; to pass...
# 67  36526  CROSS  v. t.  To pass as objects going in an opposite direct...
# 68  36527  CROSS  v. t.  To run counter to; to thwart; to obstruct; to ...
# 69  36528  CROSS  v. t.                To interfere and cut off; to debar.
# 70  36529  CROSS  v. t.  To make the sign of the cross upon; -- followe...
# 71  36530  CROSS  v. t.  To cancel by marking crosses on or over or dra...
# 72  36531  CROSS  v. t.  To cause to interbreed; -- said of different s...
# 73  36532  CROSS  v. i.                              To lie or be athwart.
# 74  36533  CROSS  v. i.  To move or pass from one side to the other or ...
# 75  36534  CROSS  v. i.                                To be inconsistent.
# 76  36535  CROSS  v. i.    To interbreed as races; to mix distinct breeds.
#
#                                               stemmed
# 46  gibbet consist two piec timber place transvers...
# 47  sign mark cross made finger ink etc actual rep...
# 48  affict regard test patienc virtu trial disappo...
# 49  piec money stamp figur cross also side piec cr...
# 50  appendag ornament anyth form cross badg orname...
# 51  monument form cross surmount cross set public ...
# 52        common herald bear mani varieti see illustr
# 53  crosslik mark symbol use instead signatur unab...
# 54                                        church land
# 55                       line drawn across anoth line
# 56  mix breed stock especi cattl breed product int...
# 57     instrument lay offset perpendicular main cours
# 58     pipe fit four branch axe usual form right angl
# 59  parallel lie fall athwart transvers obliqu int...
# 60  accord wish expect interrupt advers contrari t...
# 61  character state peevish fret ill humor cross m...
# 62  made opposit direct invers relat mutual invers...
# 63                                     athwart across
# 64        put across athwart caus intersect cross arm
# 65           lay draw someth line across cross letter
# 66       pass one side pass move travers cross stream
# 67                 pass object go opposit direct time
# 68  run counter thwart obstruct hinder clash interfer
# 69                                 interfer cut debar
# 70   make sign cross upon follow reflex pronoun cross
# 71  cancel mark cross draw line across eras usual ...
# 72     caus interbre said differ stock race mix breed
# 73                                        lie athwart
# 74  move pass one side place place make transit cr...
# 75                                          inconsist
# 76                   interbre race mix distinct breed

# %%
vectorizer = TfidfVectorizer()

# %%
dict_df_vecs = vectorizer.fit_transform(dict_df["stemmed"])

dict_df_vecs.shape
# Out:
# (207, 954)

# %%
matrix = dict_df_vecs.toarray()

# %%
def cosine_similarity(a, b):
    return np.dot(a,b)/(norm(a)*norm(b))

# %%
similarities = []

for i in range(len(matrix)):
    a = matrix[i]
    for j in range(i, len(matrix)):
        b = matrix[j]
        if dict_df.iloc[i]["Word"] != dict_df.iloc[j]["Word"]:
            similarities.append([dict_df.iloc[i]["Word"], dict_df.iloc[j]["Word"], cosine_similarity(a, b)])
            
df = pd.DataFrame(similarities, columns=["word_1", "word_2", "similarity"])

df
# Out:
#          word_1  word_2  similarity
# 0           BOB  CIRCLE         0.0
# 1           BOB  CIRCLE         0.0
# 2           BOB  CIRCLE         0.0
# 3           BOB  CIRCLE         0.0
# 4           BOB  CIRCLE         0.0
# ...         ...     ...         ...
# 19235  TRIANGLE   WEAVE         0.0
# 19236  TRIANGLE   WEAVE         0.0
# 19237  TRIANGLE   WEAVE         0.0
# 19238  TRIANGLE   WEAVE         0.0
# 19239  TRIANGLE   WEAVE         0.0
#
# [19240 rows x 3 columns]

# %%
df = df.groupby(['word_1', 'word_2'])['similarity'].max().reset_index()

df
# Out:
#       word_1    word_2  similarity
# 0        BOB    CIRCLE    0.256226
# 1        BOB      CRAB    0.152656
# 2        BOB     CROSS    0.225227
# 3        BOB   DIAMOND    0.227498
# 4        BOB     FEAST    0.000000
# ..       ...       ...         ...
# 86    SQUARE  TRIANGLE    0.526101
# 87    SQUARE     WEAVE    0.222683
# 88     SQUID  TRIANGLE    0.104468
# 89     SQUID     WEAVE    0.000000
# 90  TRIANGLE     WEAVE    0.201991
#
# [91 rows x 3 columns]

# %%
df = df.drop_duplicates()
df = df.dropna()
df = df.sort_values(by="similarity", ascending=False)

df
# Out:
#      word_1    word_2  similarity
# 86   SQUARE  TRIANGLE    0.526101
# 42    CROSS    SQUARE    0.465133
# 23   CIRCLE  TRIANGLE    0.362474
# 51  DIAMOND    SQUARE    0.337067
# 39    CROSS      HOOK    0.304220
# ..      ...       ...         ...
# 60    FEAST     SQUID    0.000000
# 61    FEAST  TRIANGLE    0.000000
# 4       BOB     FEAST    0.000000
# 27     CRAB     FEAST    0.000000
# 89    SQUID     WEAVE    0.000000
#
# [91 rows x 3 columns]

# %%
relation_dict = {}

for i, n in df.iterrows():
    word1 = n["word_1"]
    word2 = n["word_2"]
    
    key1 = (word1, word2)
    key2 = (word2, word1)
    
    relation_dict[key1] = n["similarity"]
    relation_dict[key2] = n["similarity"]

relation_dict
# Out:
# {('SQUARE', 'TRIANGLE'): 0.5261006864445218,
#  ('TRIANGLE', 'SQUARE'): 0.5261006864445218,
#  ('CROSS', 'SQUARE'): 0.46513253136953064,
#  ('SQUARE', 'CROSS'): 0.46513253136953064,
#  ('CIRCLE', 'TRIANGLE'): 0.36247386502140505,
#  ('TRIANGLE', 'CIRCLE'): 0.36247386502140505,
#  ('DIAMOND', 'SQUARE'): 0.33706745303723845,
#  ('SQUARE', 'DIAMOND'): 0.33706745303723845,
#  ('CROSS', 'HOOK'): 0.30422047036406785,
#  ('HOOK', 'CROSS'): 0.30422047036406785,
#  ('CROSS', 'DIAMOND'): 0.2652865077421948,
#  ('DIAMOND', 'CROSS'): 0.2652865077421948,
#  ('BOB', 'WEAVE'): 0.26273024274388873,
#  ('WEAVE', 'BOB'): 0.26273024274388873,
#  ('BOB', 'CIRCLE'): 0.25622611122489114,
#  ('CIRCLE', 'BOB'): 0.25622611122489114,
#  ('CROSS', 'TRIANGLE'): 0.2489146651513087,
#  ('TRIANGLE', 'CROSS'): 0.2489146651513087,
#  ('BOB', 'HOOK'): 0.23427738192711864,
#  ('HOOK', 'BOB'): 0.23427738192711864,
#  ('SPONGE', 'SQUID'): 0.23294782545555318,
#  ('SQUID', 'SPONGE'): 0.23294782545555318,
#  ('CROSS', 'RAY'): 0.23064930537589734,
#  ('RAY', 'CROSS'): 0.23064930537589734,
#  ('BOB', 'DIAMOND'): 0.2274977140853696,
#  ('DIAMOND', 'BOB'): 0.2274977140853696,
#  ('CIRCLE', 'SQUARE'): 0.22655668453249367,
#  ('SQUARE', 'CIRCLE'): 0.22655668453249367,
#  ('BOB', 'CROSS'): 0.22522743626101177,
#  ('CROSS', 'BOB'): 0.22522743626101177,
#  ('SQUARE', 'WEAVE'): 0.2226833482303552,
#  ('WEAVE', 'SQUARE'): 0.2226833482303552,
#  ('CRAB', 'TRIANGLE'): 0.22106229525218463,
#  ('TRIANGLE', 'CRAB'): 0.22106229525218463,
#  ('CIRCLE', 'CROSS'): 0.21398798369937214,
#  ('CROSS', 'CIRCLE'): 0.21398798369937214,
#  ('DIAMOND', 'RAY'): 0.21312137249841134,
#  ('RAY', 'DIAMOND'): 0.21312137249841134,
#  ('FREE', 'SPONGE'): 0.212079343416671,
#  ('SPONGE', 'FREE'): 0.212079343416671,
#  ('BOB', 'SPONGE'): 0.21161081345391822,
#  ('SPONGE', 'BOB'): 0.21161081345391822,
#  ('CIRCLE', 'RAY'): 0.20668745055858773,
#  ('RAY', 'CIRCLE'): 0.20668745055858773,
#  ('TRIANGLE', 'WEAVE'): 0.20199119002049176,
#  ('WEAVE', 'TRIANGLE'): 0.20199119002049176,
#  ('BOB', 'SQUARE'): 0.19695143907599752,
#  ('SQUARE', 'BOB'): 0.19695143907599752,
#  ('HOOK', 'SQUID'): 0.19566740033213223,
#  ('SQUID', 'HOOK'): 0.19566740033213223,
#  ('CROSS', 'SPONGE'): 0.1902652612659004,
#  ('SPONGE', 'CROSS'): 0.1902652612659004,
#  ('CIRCLE', 'HOOK'): 0.1892132704753763,
#  ('HOOK', 'CIRCLE'): 0.1892132704753763,
#  ('RAY', 'SQUID'): 0.18554717444909477,
#  ('SQUID', 'RAY'): 0.18554717444909477,
#  ('CIRCLE', 'DIAMOND'): 0.18282761180281165,
#  ('DIAMOND', 'CIRCLE'): 0.18282761180281165,
#  ('BOB', 'RAY'): 0.1815718038877817,
#  ('RAY', 'BOB'): 0.1815718038877817,
#  ('CROSS', 'FREE'): 0.1806748217946738,
#  ('FREE', 'CROSS'): 0.1806748217946738,
#  ('DIAMOND', 'HOOK'): 0.1788222715077181,
#  ('HOOK', 'DIAMOND'): 0.1788222715077181,
#  ('DIAMOND', 'TRIANGLE'): 0.17406321486604467,
#  ('TRIANGLE', 'DIAMOND'): 0.17406321486604467,
#  ('SPONGE', 'SQUARE'): 0.17305071074913134,
#  ('SQUARE', 'SPONGE'): 0.17305071074913134,
#  ('RAY', 'SQUARE'): 0.17201089581348042,
#  ('SQUARE', 'RAY'): 0.17201089581348042,
#  ('CIRCLE', 'CRAB'): 0.17181027057641995,
#  ('CRAB', 'CIRCLE'): 0.17181027057641995,
#  ('CROSS', 'FEAST'): 0.16758143832876604,
#  ('FEAST', 'CROSS'): 0.16758143832876604,
#  ('RAY', 'SPONGE'): 0.15375783662121165,
#  ('SPONGE', 'RAY'): 0.15375783662121165,
#  ('BOB', 'CRAB'): 0.15265620534904273,
#  ('CRAB', 'BOB'): 0.15265620534904273,
#  ('FREE', 'SQUARE'): 0.15240426766949905,
#  ('SQUARE', 'FREE'): 0.15240426766949905,
#  ('HOOK', 'SQUARE'): 0.1500528255091514,
#  ('SQUARE', 'HOOK'): 0.1500528255091514,
#  ('BOB', 'FREE'): 0.14761147517069742,
#  ('FREE', 'BOB'): 0.14761147517069742,
#  ('SPONGE', 'WEAVE'): 0.14743637800322462,
#  ('WEAVE', 'SPONGE'): 0.14743637800322462,
#  ('FEAST', 'SPONGE'): 0.14715197298496419,
#  ('SPONGE', 'FEAST'): 0.14715197298496419,
#  ('DIAMOND', 'FREE'): 0.14690162045600688,
#  ('FREE', 'DIAMOND'): 0.14690162045600688,
#  ('SQUARE', 'SQUID'): 0.14498987037691483,
#  ('SQUID', 'SQUARE'): 0.14498987037691483,
#  ('CRAB', 'SQUARE'): 0.14433576781088514,
#  ('SQUARE', 'CRAB'): 0.14433576781088514,
#  ('CRAB', 'CROSS'): 0.1415635919069906,
#  ('CROSS', 'CRAB'): 0.1415635919069906,
#  ('HOOK', 'TRIANGLE'): 0.13763898478376022,
#  ('TRIANGLE', 'HOOK'): 0.13763898478376022,
#  ('FREE', 'WEAVE'): 0.1370262657493726,
#  ('WEAVE', 'FREE'): 0.1370262657493726,
#  ('FREE', 'RAY'): 0.1342107351297033,
#  ('RAY', 'FREE'): 0.1342107351297033,
#  ('FREE', 'TRIANGLE'): 0.12191584887627331,
#  ('TRIANGLE', 'FREE'): 0.12191584887627331,
#  ('DIAMOND', 'SPONGE'): 0.12188856844729161,
#  ('SPONGE', 'DIAMOND'): 0.12188856844729161,
#  ('HOOK', 'SPONGE'): 0.11843706680842098,
#  ('SPONGE', 'HOOK'): 0.11843706680842098,
#  ('FEAST', 'FREE'): 0.11329638443313163,
#  ('FREE', 'FEAST'): 0.11329638443313163,
#  ('HOOK', 'RAY'): 0.11281189508883908,
#  ('RAY', 'HOOK'): 0.11281189508883908,
#  ('BOB', 'TRIANGLE'): 0.10928434325062303,
#  ('TRIANGLE', 'BOB'): 0.10928434325062303,
#  ('CIRCLE', 'FREE'): 0.10905816597877149,
#  ('FREE', 'CIRCLE'): 0.10905816597877149,
#  ('CROSS', 'WEAVE'): 0.10777365452410753,
#  ('WEAVE', 'CROSS'): 0.10777365452410753,
#  ('CROSS', 'SQUID'): 0.10775363526121168,
#  ('SQUID', 'CROSS'): 0.10775363526121168,
#  ('CRAB', 'RAY'): 0.10706869671998745,
#  ('RAY', 'CRAB'): 0.10706869671998745,
#  ('SQUID', 'TRIANGLE'): 0.10446824465504857,
#  ('TRIANGLE', 'SQUID'): 0.10446824465504857,
#  ('RAY', 'TRIANGLE'): 0.09890264877881853,
#  ('TRIANGLE', 'RAY'): 0.09890264877881853,
#  ('CRAB', 'SQUID'): 0.09165226334431244,
#  ('SQUID', 'CRAB'): 0.09165226334431244,
#  ('CRAB', 'SPONGE'): 0.08662138092679429,
#  ('SPONGE', 'CRAB'): 0.08662138092679429,
#  ('CRAB', 'FREE'): 0.08356443368534885,
#  ('FREE', 'CRAB'): 0.08356443368534885,
#  ('FREE', 'HOOK'): 0.08250041810980378,
#  ('HOOK', 'FREE'): 0.08250041810980378,
#  ('CRAB', 'DIAMOND'): 0.07944564934055123,
#  ('DIAMOND', 'CRAB'): 0.07944564934055123,
#  ('CIRCLE', 'SQUID'): 0.07854250407508995,
#  ('SQUID', 'CIRCLE'): 0.07854250407508995,
#  ('CRAB', 'WEAVE'): 0.07054616108378413,
#  ('WEAVE', 'CRAB'): 0.07054616108378413,
#  ('CRAB', 'HOOK'): 0.07007608303442268,
#  ('HOOK', 'CRAB'): 0.07007608303442268,
#  ('CIRCLE', 'WEAVE'): 0.06940196901689183,
#  ('WEAVE', 'CIRCLE'): 0.06940196901689183,
#  ('CIRCLE', 'FEAST'): 0.0692599128861724,
#  ('FEAST', 'CIRCLE'): 0.0692599128861724,
#  ('FEAST', 'RAY'): 0.06756861793038293,
#  ('RAY', 'FEAST'): 0.06756861793038293,
#  ('CIRCLE', 'SPONGE'): 0.06635972572606641,
#  ('SPONGE', 'CIRCLE'): 0.06635972572606641,
#  ('BOB', 'SQUID'): 0.0638810818815905,
#  ('SQUID', 'BOB'): 0.0638810818815905,
#  ('SPONGE', 'TRIANGLE'): 0.06091565954061027,
#  ('TRIANGLE', 'SPONGE'): 0.06091565954061027,
#  ('HOOK', 'WEAVE'): 0.060026132989481895,
#  ('WEAVE', 'HOOK'): 0.060026132989481895,
#  ('FEAST', 'SQUARE'): 0.05299508668275793,
#  ('SQUARE', 'FEAST'): 0.05299508668275793,
#  ('DIAMOND', 'SQUID'): 0.04779484040884601,
#  ('SQUID', 'DIAMOND'): 0.04779484040884601,
#  ('DIAMOND', 'WEAVE'): 0.04696388628406861,
#  ('WEAVE', 'DIAMOND'): 0.04696388628406861,
#  ('FREE', 'SQUID'): 0.03844042568639622,
#  ('SQUID', 'FREE'): 0.03844042568639622,
#  ('RAY', 'WEAVE'): 0.035978248314086275,
#  ('WEAVE', 'RAY'): 0.035978248314086275,
#  ('DIAMOND', 'FEAST'): 0.0,
#  ('FEAST', 'DIAMOND'): 0.0,
#  ('FEAST', 'WEAVE'): 0.0,
#  ('WEAVE', 'FEAST'): 0.0,
#  ('FEAST', 'HOOK'): 0.0,
#  ('HOOK', 'FEAST'): 0.0,
#  ('FEAST', 'SQUID'): 0.0,
#  ('SQUID', 'FEAST'): 0.0,
#  ('FEAST', 'TRIANGLE'): 0.0,
#  ('TRIANGLE', 'FEAST'): 0.0,
#  ('BOB', 'FEAST'): 0.0,
#  ('FEAST', 'BOB'): 0.0,
#  ('CRAB', 'FEAST'): 0.0,
#  ('FEAST', 'CRAB'): 0.0,
#  ('SQUID', 'WEAVE'): 0.0,
#  ('WEAVE', 'SQUID'): 0.0}

# %%
sim_4 = []

def similarity_4(a, b, c, d):
    return relation_dict[(a, b)] + relation_dict[(a, c)] + relation_dict[(a, d)] + relation_dict[(b, c)] + relation_dict[(b, d)] + relation_dict[(c, d)]

for i, a in enumerate(words):
    for j in range(i + 1, len(words)):
        b = words[j]
        for k in range(j + 1, len(words)):
            c = words[k]
            for l in range(k + 1, len(words)):
                d = words[l]
                try:
                    score = similarity_4(a, b, c, d)
                        
                    index = 0
                    
                    while index < len(sim_4) and score < sim_4[index][1]:
                        index += 1
                    sim_4.insert(index, ([a, b, c, d], score))
                except:
                    pass
                    

sim_4

print(similarity_4("CRAB", "RAY", "SPONGE", "SQUID"))
# Out:
# 0.8575951775169537
